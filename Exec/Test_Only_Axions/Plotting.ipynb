# %%
import numpy as np
import scipy as sp 
import matplotlib.pyplot as plt
import yt
# %matplotlib notebook

# %%
ds = yt.load("~/astrosoftware/axionyx/Exec/Test_Only_Axions/MFAB_plot111")
print(ds.field_list)
rhs = ds.r["rhs"]

ad = ds.all_data()
rhs = ad["rhs"]
print(ad) #shows positions and units of the axes 

print(np.max(rhs))

# slc = yt.SlicePlot(ds, "z", "rhs", center=("max","rhs"))
slc = yt.SlicePlot(ds, "z", "rhs", center=[0.256, 0.256, 0])
# slc = yt.SlicePlot(ds, "z", "rhs", center=[0, 0, 0])

# slc.set_zlim('rhs', -2, 2)

slc.show()
# Out:
# yt : [INFO     ] 2019-03-07 16:06:59,392 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-03-07 16:06:59,392 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-03-07 16:06:59,393 Parameters: domain_left_edge          = [-0. -0. -0.]
# yt : [INFO     ] 2019-03-07 16:06:59,394 Parameters: domain_right_edge         = [0.512 0.512 0.512]
# [('boxlib', 'rhs')]
# YTRegion (MFAB_plot111): , center=[0.256 0.256 0.256] cm, left_edge=[-0. -0. -0.] cm, right_edge=[0.512 0.512 0.512] cm
# 1.406471255404853e-231 dimensionless
# yt : [INFO     ] 2019-03-07 16:06:59,555 xlim = 0.000000 0.512000
# yt : [INFO     ] 2019-03-07 16:06:59,558 ylim = 0.000000 0.512000
# yt : [INFO     ] 2019-03-07 16:06:59,561 xlim = 0.000000 0.512000
# yt : [INFO     ] 2019-03-07 16:06:59,563 ylim = 0.000000 0.512000
# yt : [INFO     ] 2019-03-07 16:06:59,565 Making a fixed resolution buffer of (('boxlib', 'rhs')) 800 by 800
# ...
