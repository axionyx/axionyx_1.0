# %%
import numpy as np
import scipy as sp 
import matplotlib.pyplot as plt
import yt
# %matplotlib notebook

# %%
ds = yt.load("~/astrosoftware/axionyx/Exec/Test_Only_Axions/MFAB_plot100")
print(ds.field_list)
rhs = ds.r["rhs"]

ad = ds.all_data()
rhs = ad["rhs"]
print(ad) #shows positions and units of the axes 

print(np.max(rhs))

# slc = yt.SlicePlot(ds, "z", "rhs", center=("max","rhs"))
slc = yt.SlicePlot(ds, "z", "rhs", center=[0.256, 0.256, 0])
# slc = yt.SlicePlot(ds, "z", "rhs", center=[0, 0, 0])

# slc.set_zlim('rhs', -2, 2)

slc.show()
# Out:
# yt : [INFO     ] 2019-03-07 14:29:22,322 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-03-07 14:29:22,323 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2019-03-07 14:29:22,325 Parameters: domain_left_edge          = [-0. -0. -0.]
# yt : [INFO     ] 2019-03-07 14:29:22,327 Parameters: domain_right_edge         = [0.512 0.512 0.512]
# [('boxlib', 'rhs')]
# /Users/mateja/anaconda3/lib/python3.7/site-packages/yt/units/yt_array.py:557: RuntimeWarning: invalid value encountered in multiply
#   values *= conversion_factor
# YTRegion (MFAB_plot100): , center=[0.256 0.256 0.256] cm, left_edge=[-0. -0. -0.] cm, right_edge=[0.512 0.512 0.512] cm
# /Users/mateja/anaconda3/lib/python3.7/site-packages/yt/units/yt_array.py:1373: RuntimeWarning: invalid value encountered in reduce
#   out_arr = func(np.asarray(inp), out=out, **kwargs)
# nan dimensionless
# yt : [INFO     ] 2019-03-07 14:29:22,503 xlim = 0.000000 0.512000
# yt : [INFO     ] 2019-03-07 14:29:22,504 ylim = 0.000000 0.512000
# yt : [INFO     ] 2019-03-07 14:29:22,507 xlim = 0.000000 0.512000
# yt : [INFO     ] 2019-03-07 14:29:22,510 ylim = 0.000000 0.512000
# yt : [INFO     ] 2019-03-07 14:29:22,515 Making a fixed resolution buffer of (('boxlib', 'rhs')) 800 by 800
# /Users/mateja/anaconda3/lib/python3.7/site-packages/yt/visualization/plot_window.py:788: RuntimeWarning: All-NaN axis encountered
#   elif np.nanmax(image) == np.nanmin(image):
# /Users/mateja/anaconda3/lib/python3.7/site-packages/yt/visualization/plot_window.py:791: RuntimeWarning: All-NaN axis encountered
#   elif np.nanmax(image) <= 0:
# yt : [WARNING  ] 2019-03-07 14:29:22,563 Plot image for field ('boxlib', 'rhs') is filled with NaNs.
# yt : [WARNING  ] 2019-03-07 14:29:22,564 Switching to linear colorbar scaling.
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
